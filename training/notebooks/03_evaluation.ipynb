# %% [markdown]
# # PyroSense AI — Evaluation & Grad-CAM\n\nThis notebook evaluates the classifier and visualizes explainability outputs.

# %%
import numpy as np\nfrom PIL import Image\nfrom inference.gradcam_explainer import GradCamExplainer\n\nimg = np.zeros((256,256,3), dtype=np.uint8)\nexpl = GradCamExplainer()\nthree = expl.generate_heatmap(img)\nImage.fromarray(three[:,:,::-1])
