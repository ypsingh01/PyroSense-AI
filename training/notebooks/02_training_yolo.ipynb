# %% [markdown]
# # PyroSense AI — YOLOv8 Training Walkthrough\n\nThis notebook demonstrates how to fine-tune YOLOv8 with MLflow logging using the project scripts.

# %%
# !pip install -r ../../requirements.txt -q

# %%
# Download datasets\n!python ../../data/download_datasets.py

# %%
# Train YOLOv8 with MLflow autologging\n!python ../../training/train_yolo.py --epochs 25 --imgsz 640 --batch 16
