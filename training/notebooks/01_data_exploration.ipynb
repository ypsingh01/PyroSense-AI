# %% [markdown]
# # PyroSense AI — Data Exploration\n\nThis notebook explores dataset structure, class balance, and sample visualizations.

# %%
from pathlib import Path\nimport pandas as pd\nimport matplotlib.pyplot as plt\n\ndata_root = Path('../..') / 'data'\nraw = data_root / 'raw'\nprocessed = data_root / 'processed'\nraw, processed

# %%
samples = list((data_root / 'samples').glob('*.jpg')) + list((data_root / 'samples').glob('*.png'))\nlen(samples), samples[:3]
